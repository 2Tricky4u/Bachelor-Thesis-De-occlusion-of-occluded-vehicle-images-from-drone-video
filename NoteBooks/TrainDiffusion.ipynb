# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd gdrive/MyDrive/'Colab Notebooks'/improved-diffusion
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/improved-diffusion

# %%
pip install -e .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/gdrive/MyDrive/Colab%20Notebooks/improved-diffusion
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 KB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 86.9 MB/s eta 0:00:00
# ...
#   Running setup.py develop for improved-diffusion
# ...

# %%
pip install mpi4py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 78.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for mpi4py: filename=mpi4py-3.1.4-cp39-cp39-linux_x86_64.whl size=3380619 sha256=8ff77a9f5d1a34a87e6cb4b38504b76124a4271d79e2627fe841eebc621040ac
#   Stored in directory: /root/.cache/pip/wheels/db/81/9f/43a031fce121c845baca1c5d9a1468cad98208286aa2832de9
# Successfully built mpi4py
# ...

# %%
# !python scripts/image_train.py --data_dir datasets/car --image_size 64 --num_channels 128 --num_res_blocks 2 --learn_sigma True --diffusion_steps 4000 --noise_schedule cosine --lr 1e-4 --batch_size 5 --save_interval 100 --resume_checkpoint="./tmp/ema_0.9999_000900.pt"
# Out:
# Logging to ./tmp
# creating model and diffusion...
# creating data loader...
# training...
# loading model from checkpoint: ./tmp/ema_0.9999_000900.pt...
# ------------------------
# | grad_norm | 2.35     |
# | loss      | 0.943    |
# | loss_q0   | 0.987    |
# | loss_q1   | 0.939    |
# | loss_q2   | 0.901    |
# | mse       | 0.931    |
# | mse_q0    | 0.963    |
# | mse_q1    | 0.934    |
# | mse_q2    | 0.897    |
# | samples   | 5        |
# | step      | 0        |
# | vb        | 0.0126   |
# | vb_q0     | 0.0245   |
# | vb_q1     | 0.00544  |
# | vb_q2     | 0.00429  |
# ------------------------
# saving model 0...
# saving model 0.9999...
# ------------------------
# | grad_norm | 2.77     |
# | loss      | 0.86     |
# | loss_q0   | 1.06     |
# | loss_q1   | 0.772    |
# | loss_q2   | 0.774    |
# | loss_q3   | 0.797    |
# | mse       | 0.802    |
# | mse_q0    | 0.873    |
# | mse_q1    | 0.768    |
# | mse_q2    | 0.77     |
# | mse_q3    | 0.782    |
# ...

# %%
ls
# Out:
# gdrive/  sample_data/
