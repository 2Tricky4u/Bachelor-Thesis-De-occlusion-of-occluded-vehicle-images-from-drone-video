# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/MyDrive/'Colab Notebooks'/guided-diffusion
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/guided-diffusion

# %%
# !unzip "./datasets/gt.zip" -d "./datasets/"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./datasets/gt/02377.jpg
#   inflating: ./datasets/gt/02378.jpg
#   inflating: ./datasets/gt/02379.jpg
#   inflating: ./datasets/gt/02380.jpg
#   inflating: ./datasets/gt/02381.jpg
#   inflating: ./datasets/gt/02382.jpg
#   inflating: ./datasets/gt/02383.jpg
#   inflating: ./datasets/gt/02384.jpg
#   inflating: ./datasets/gt/02385.jpg
#   inflating: ./datasets/gt/02386.jpg
#   inflating: ./datasets/gt/02387.jpg
#   inflating: ./datasets/gt/02388.jpg
#   inflating: ./datasets/gt/02389.jpg
#   inflating: ./datasets/gt/02390.jpg
#   inflating: ./datasets/gt/02391.jpg
#   inflating: ./datasets/gt/02392.jpg
#   inflating: ./datasets/gt/02393.jpg
#   inflating: ./datasets/gt/02394.jpg
#   inflating: ./datasets/gt/02395.jpg
#   inflating: ./datasets/gt/02396.jpg
#   inflating: ./datasets/gt/02397.jpg
#   inflating: ./datasets/gt/02398.jpg
#   inflating: ./datasets/gt/02399.jpg
#   inflating: ./datasets/gt/02400.jpg
# ...

# %%
pip install -e .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/gdrive/MyDrive/Colab%20Notebooks/guided-diffusion
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 71.0 MB/s eta 0:00:00
# ...
#   Running setup.py develop for guided-diffusion
# ...

# %%
pip install mpi4py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 62.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for mpi4py: filename=mpi4py-3.1.4-cp310-cp310-linux_x86_64.whl size=3365690 sha256=112446562e7cd2eb8139aadb158f090ee31e0801fa41dcfb623b8cf24325da0a
#   Stored in directory: /root/.cache/pip/wheels/e8/1b/b5/97ec4cfccdde26e0f3590ad6e09a5242d508dff09704ef86c1
# Successfully built mpi4py
# ...

# %%
# !nvidia-smi
# Out:
# Tue May 16 15:01:29 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0    24W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !python scripts/image_train.py --data_dir ./datasets/gt/ --image_size 128 --num_channels 256 --num_res_blocks 2 --learn_sigma True --diffusion_steps 1000 --noise_schedule linear --lr 1e-4 --batch_size 4 --save_interval 1000
# Out:
# Logging to /tmp/openai-2023-05-16-15-35-28-065232
# creating model and diffusion...
# creating data loader...
# training...
# -------------------------
# | grad_norm  | 4.02     |
# | loss       | 1.01     |
# | loss_q0    | 1.02     |
# | loss_q1    | 1.01     |
# | loss_q2    | 1.01     |
# | mse        | 0.999    |
# | mse_q0     | 0.998    |
# | mse_q1     | 1        |
# | mse_q2     | 0.999    |
# | param_norm | 287      |
# | samples    | 4        |
# | step       | 0        |
# | vb         | 0.0136   |
# | vb_q0      | 0.0274   |
# | vb_q1      | 0.00748  |
# | vb_q2      | 0.00978  |
# -------------------------
# saving model 0...
# saving model 0.9999...
# -------------------------
# | grad_norm  | 4.18     |
# | loss       | 0.83     |
# | loss_q0    | 0.935    |
# | loss_q1    | 0.792    |
# | loss_q2    | 0.804    |
# | loss_q3    | 0.804    |
# | mse        | 0.814    |
# | mse_q0     | 0.89     |
# | mse_q1     | 0.786    |
# | mse_q2     | 0.797    |
# ...
